# %% [markdown]
# # Pretty Print Test
# > Testing out pretty print na d

# %%
# ------------------------------------------------------
from rich import print as rprint # For rprinting
from rich.pretty import pprint # For pretty printing
from rich import inspect # For inspect
from rich.console import Console # For console.print
from rich.markdown import Markdown # For markdown
from rich.panel import Panel # For Panel()
from rich import box # For Panel Boxes
from rich.prompt import Prompt # For Prompting 
console = Console() # Standard code to access console
# -------------------------------------------------------

# %%
# Print system time 
import time

currentTime = time.time()

rprint(currentTime)
inspect(currentTime, all=True)
# Out:
# 1709448397.653307
# ╭──────────────────────────────────────────────── <class 'float'> ────────────────────────────────────────────────╮
# │ Convert a string or number to a floating point number, if possible.                                             │
# │                                                                                                                 │
# │ ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────╮ │
# │ │ 1709448397.653307                                                                                           │ │
# │ ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────╯ │
# │                                                                                                                 │
# │           __doc__ = 'Convert a string or number to a floating point number, if possible.'                       │
# │              imag = 0.0                                                                                         │
# │              real = 1709448397.653307                                                                           │
# │           __abs__ = def __abs__(): abs(self)                                                                    │
# │           __add__ = def __add__(value, /): Return self+value.                                                   │
# │  as_integer_ratio = def as_integer_ratio(): Return integer ratio.                                               │
# │          __bool__ = def __bool__(): True if self else False                                                     │
# │          __ceil__ = def __ceil__(): Return the ceiling as an Integral.                                          │
# │         __class__ = class __class__(x=0, /): Convert a string or number to a floating point number, if          │
# │                     possible.                                                                                   │
# │         conjugate = def conjugate(): Return self, the complex conjugate of any float.                           │
# │       __delattr__ = def __delattr__(name, /): Implement delattr(self, name).                                    │
# │           __dir__ = def __dir__(): Default dir() implementation.                                                │
# │        __divmod__ = def __divmod__(value, /): Return divmod(self, value).                                       │
# │            __eq__ = def __eq__(value, /): Return self==value.                                                   │
# │         __float__ = def __float__(): float(self)                                                                │
# │         __floor__ = def __floor__(): Return the floor as an Integral.                                           │
# │      __floordiv__ = def __floordiv__(value, /): Return self//value.                                             │
# │        __format__ = def __format__(format_spec, /): Formats the float according to format_spec.                 │
# │           fromhex = def fromhex(string, /): Create a floating-point number from a hexadecimal string.           │
# │            __ge__ = def __ge__(value, /): Return self>=value.                                                   │
# │  __getattribute__ = def __getattribute__(name, /): Return getattr(self, name).                                  │
# │     __getformat__ = def __getformat__(typestr, /): You probably don't want to use this function.                │
# │    __getnewargs__ = def __getnewargs__():                                                                       │
# │            __gt__ = def __gt__(value, /): Return self>value.                                                    │
# │          __hash__ = def __hash__(): Return hash(self).                                                          │
# │               hex = def hex(): Return a hexadecimal representation of a floating-point number.                  │
# │          __init__ = def __init__(*args, **kwargs): Initialize self.  See help(type(self)) for accurate          │
# │                     signature.                                                                                  │
# │ __init_subclass__ = def __init_subclass__(...) This method is called when a class is subclassed.                │
# │           __int__ = def __int__(): int(self)                                                                    │
# │        is_integer = def is_integer(): Return True if the float is an integer.                                   │
# │            __le__ = def __le__(value, /): Return self<=value.                                                   │
# │            __lt__ = def __lt__(value, /): Return self<value.                                                    │
# │           __mod__ = def __mod__(value, /): Return self%value.                                                   │
# │           __mul__ = def __mul__(value, /): Return self*value.                                                   │
# │            __ne__ = def __ne__(value, /): Return self!=value.                                                   │
# │           __neg__ = def __neg__(): -self                                                                        │
# │           __new__ = def __new__(*args, **kwargs): Create and return a new object.  See help(type) for accurate  │
# │                     signature.                                                                                  │
# │           __pos__ = def __pos__(): +self                                                                        │
# │           __pow__ = def __pow__(value, mod=None, /): Return pow(self, value, mod).                              │
# │          __radd__ = def __radd__(value, /): Return value+self.                                                  │
# │       __rdivmod__ = def __rdivmod__(value, /): Return divmod(value, self).                                      │
# │        __reduce__ = def __reduce__(): Helper for pickle.                                                        │
# │     __reduce_ex__ = def __reduce_ex__(protocol, /): Helper for pickle.                                          │
# │          __repr__ = def __repr__(): Return repr(self).                                                          │
# │     __rfloordiv__ = def __rfloordiv__(value, /): Return value//self.                                            │
# │          __rmod__ = def __rmod__(value, /): Return value%self.                                                  │
# │          __rmul__ = def __rmul__(value, /): Return value*self.                                                  │
# │         __round__ = def __round__(ndigits=None, /): Return the Integral closest to x, rounding half toward      │
# │                     even.                                                                                       │
# │          __rpow__ = def __rpow__(value, mod=None, /): Return pow(value, self, mod).                             │
# │          __rsub__ = def __rsub__(value, /): Return value-self.                                                  │
# │      __rtruediv__ = def __rtruediv__(value, /): Return value/self.                                              │
# │       __setattr__ = def __setattr__(name, value, /): Implement setattr(self, name, value).                      │
# │     __setformat__ = def __setformat__(typestr, fmt, /): You probably don't want to use this function.           │
# │        __sizeof__ = def __sizeof__(): Size of object in memory, in bytes.                                       │
# │           __str__ = def __str__(): Return str(self).                                                            │
# │           __sub__ = def __sub__(value, /): Return self-value.                                                   │
# │  __subclasshook__ = def __subclasshook__(...) Abstract classes can override this to customize issubclass().     │
# │       __truediv__ = def __truediv__(value, /): Return self/value.                                               │
# │         __trunc__ = def __trunc__(): Return the Integral closest to x between 0 and x.                          │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
